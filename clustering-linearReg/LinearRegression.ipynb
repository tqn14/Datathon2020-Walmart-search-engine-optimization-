# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer

# %%
path = r'C:\Users\quynh\Documents'
all_files = glob.glob(path + "/*.csv")

# %%
li = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=None)
    li.append(df)

dfframe = pd.concat(li, axis=0, ignore_index=True, sort = False)

# %%
dfframe
# Out:
#                                                       0        1    2  \
# 0            Logitech Wireless Keyboard and Mouse Combo   $17.88  4.5
# 1                    Apple Lightning to USB Cable, 3 ft    $3.99  3.8
# 2     Straight Talk $45 Unlimited 30-Day Plan e-PIN ...   $45.00  4.4
# 3                   Straight Talk LG Journey Smartphone   $39.88  4.2
# 4     Acer 315 15.6" Celeron 4GB/32GB Chromebook, 15...  $272.88  4.6
# ...                                                 ...      ...  ...
# 3943  L.O.L. Surprise! Queen Bee – Huggable, Soft Pl...   $19.88  4.9
# 3944               Lullabrites™ Plush Animals - Unicorn   $14.84  4.7
# 3945  Fisher-Price Groove & Glow BeatBo Plush with L...   $10.08  4.6
# 3946        Rubie's Marvel Hulk Child Halloween Costume   $15.00  4.9
# 3947  Fortnite Victory Series Skull Trooper - 1 Figu...    $7.38  5.0
#
#                  3                                                  4
# 0     1155 ratings  Be more productive in a variety of situations ...
# 1      627 ratings  Get more from your devices with the Apple Ligh...
# 2     1567 ratings  e-PIN Top Up is the most flexible option for a...
# 3       98 ratings  Get the new LG Journey on Straight Talk! With ...
# 4     1112 ratings  Google Classroom Compatible! Acer Chromebook 3...
# ...            ...                                                ...
# 3943     7 ratings  Cuddle up with your favorite L.O.L. Surprise! ...
# 3944    31 ratings  Lullabrites™ Plush Unicorn Lights Up Plays Bed...
# 3945   179 ratings  BeatBo is more than a plush toy that baby can ...
# 3946     7 ratings  Watch your little Bruce Banner transform in th...
# 3947    19 ratings  Level up with the Victory Series Fortnite figu...
#
# [3948 rows x 5 columns]

# %%
df[1].interpolate(method='linear', inplace=True)

# %%
df[3].interpolate(method='linear', inplace=True)

# %%
df.head(10)
# Out:
#                                                    0       1    2  \
# 0  Fortnite SP-L Nerf Elite Dart Blaster - Detach...  $12.99  4.7
# 1  VTech Explore and Write Activity Desk Transfor...  $42.88  4.4
# 2  Playskool Friends Mr. Potato Head Classic Toy ...   $5.00  4.7
# 3  Lite Brite Ultimate Classic With 6 Templates A...  $12.82  4.4
# 4  Easy-Bake Ultimate Oven Baking Star Edition (O...  $39.97  4.2
# 5                            Smithsonian Robo Spider  $15.08  4.7
# 6  VTech Switch and Go Stegosaurus Buggy Transfor...   $9.99  4.8
# 7  L.O.L. Surprise! Glitter Globe Doll Winter Dis...  $10.88  4.5
# 8  Leapfrog Learning Friends 100 Words Bilingual ...     NaN  4.8
# 9  Hairdorables Collectible Dolls - Series 3 (Sty...  $29.15  4.7
#
#              3                                                  4
# 0  141 ratings  The Nerf Fortnite SP-L blaster is inspired by ...
# 1  646 ratings  The Explore and Write Activity Desk features a...
# 2  121 ratings  Playskool Friends Mr. Potato Head Classic Toy ...
# 3  308 ratings  The most fun & nostalgic way to create art wit...
# 4  601 ratings  Easy-Bake Ultimate Oven Toy, Baking Star Editi...
# 5   10 ratings  The Smithsonian Robo Spider lets you build you...
# 6   54 ratings  Stomp into the cool, crazy world of prehistori...
# 7  242 ratings  Get ready to chill out and boogie down with al...
# 8  347 ratings  Join animal friends Turtle, Tiger and Monkey a...
# 9  135 ratings  Noah and the Hairdorables are back in Series 3...

# %%
import os
import sys
import pathlib
import pickle
from collections import namedtuple
from datetime import datetime

import numpy as np
import apache_beam as beam
# import annoy
from sklearn.random_projection import gaussian_random_matrix

import tensorflow.compat.v1 as tf
import tensorflow_transform as tft
import tensorflow_hub as hub
import tensorflow_transform.beam as tft_beam

# %%
encoder = None

def embed_text(text, module_url, random_projection_matrix):
  # Beam will run this function in different processes that need to
  # import hub and load embed_fn (if not previously loaded)
  global encoder
  if not encoder:
    encoder = hub.Module(module_url)
  embedding = encoder(text)
  if random_projection_matrix is not None:
    # Perform random projection for the embedding
    embedding = tf.matmul(
        embedding, tf.cast(random_projection_matrix, embedding.dtype))
  return embedding
